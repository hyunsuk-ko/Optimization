# %% [markdown]
# We manage 2 bakeries that produce, store, and sell loaves of fresh bread on site. A given
# location lcan produce up to loaves of bread every day, and experiences different demand𝑏𝑙𝑑𝑙𝑡
# on a daily basis. We are able to store leftover bread to be sold the next day, but only if we sell the
# day-old loaves at a discount (with linearly increasing discounts if a loaf is stored for multiple
# days), so we effectively incur an opportunity cost of sper loaf that is stored overnight.
# Additionally, between one day’s closing and the next day’s opening, we can transport the stored
# loaves between the two locations, at a cost of mper loaf.
# Our goal is to minimize our costs over a seven day period, while meeting demand at each
# location for every day. Assume that we start with 0 loaves of leftover bread on the first day at
# both locations.

# %%
using Cbc, JuMP, NamedArrays

# Sets
T = [1, 2, 3, 4, 5, 6, 7] # our set of days 
T0 = [0, 1, 2, 3, 4, 5, 6, 7]
L = [1, 2] # bakery locations

# Parameters
c = 0.5 # production cost
s = 0.2 # incurred cost of selling old bread
b = Dict(zip(L, [150, 260])) # maximum # of bread produced in location
# deamnd for bread at location l at day tm
d = NamedArray([100 130 150 120 140 220 150; 150 230 200 190 280 140 320], (L, T), ("location", "day")) 
h = 0.1 # transportation cost

########################################
# TODO: create and solve general model #
########################################
using JuMP, Cbc

m = Model()

@variable(m, x[L,T] >= 0) # of bread produced at location L in day T
@variable(m, y[L,T0] >= 0) # of leftover bread at location L in day T
@variable(m, z[L,T0] >= 0) # of transporated bread from location 1 to 2 in day T

@objective(m, Min, sum(c * x[l,t] + s * y[l,t] + h * z[l,t] for t in T for l in L))

@constraint(m, initial_loc_leftover[l in L], y[l,0] == 0)
#@constraint(m, initial_loc_transport[l in L], z[l,0] == 0)
@constraint(m, max_produce[l in L], sum(x[l,t] for t in T) <= b[l])
@constraint(m, leftover_balance1[t in T], y[1,t] == y[1,t-1] + x[1,t] + z[2,t-1] - d[1,t] - z[1,t])
@constraint(m, leftover_balance2[t in T], y[2,t] == y[2,t-1] + x[2,t] + z[1,t-1] - d[2,t] - z[2,t])

set_optimizer(m, Cbc.Optimizer)

optimize!(m)

solution_summary(m, verbose=true)
# Out:
# Presolve 6 (-12) rows, 12 (-34) columns and 20 (-66) elements
# Perturbing problem by 0.001% of 0.5 - largest nonzero change 4.6794759e-05 ( 0.046794759%) - largest zero change 0
# 0  Obj 401.95006 Primal inf 760.1 (4)
# 6  Obj 788.01947
# Optimal - objective value 788
# After Postsolve, objective 788, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 788 - 6 iterations time 0.002, Presolve 0.00
# * Solver : COIN Branch-and-Cut (Cbc)
#
# * Status
#   Termination status : OPTIMAL
#   Primal status      : FEASIBLE_POINT
#   Dual status        : NO_SOLUTION
#   Result count       : 1
#   Has duals          : false
#   Message from the solver:
#   "Cbc_status          = finished - check isProvenOptimal or isProvenInfeasible to see if solution found (or check value of best solution)
# Cbc_secondaryStatus = unset (status_ will also be -1)
# "
#
# * Candidate solution
#   Objective value      : 788.0
#   Objective bound      : 788.0
#   Primal solution :
#     x[1,1] : 0.0
#     x[1,2] : 0.0
#     x[1,3] : 0.0
#     x[1,4] : 0.0
#     x[1,5] : 0.0
#     x[1,6] : 0.0
#     x[1,7] : 150.0
#     x[2,1] : 0.0
#     x[2,2] : 0.0
#     x[2,3] : 0.0
#     x[2,4] : 0.0
#     x[2,5] : 0.0
#     x[2,6] : 0.0
#     x[2,7] : 260.0
#     y[1,0] : 0.0
#     y[1,1] : 0.0
#     y[1,2] : 0.0
#     y[1,3] : 0.0
#     y[1,4] : 0.0
#     y[1,5] : 0.0
#     y[1,6] : 0.0
#     y[1,7] : 0.0
#     y[2,0] : 0.0
#     y[2,1] : 0.0
#     y[2,2] : 0.0
#     y[2,3] : 0.0
#     y[2,4] : 0.0
#     y[2,5] : 0.0
#     y[2,6] : 0.0
#     y[2,7] : 0.0
#     z[1,0] : 1160.0
#     z[1,1] : 850.0
#     z[1,2] : 880.0
#     z[1,3] : 470.0
#     z[1,4] : 560.0
#     z[1,5] : 140.0
#     z[1,6] : 60.0
#     z[1,7] : 0.0
#     z[2,0] : 950.0
#     z[2,1] : 1010.0
#     z[2,2] : 620.0
#     z[2,3] : 680.0
#     z[2,4] : 280.0
#     z[2,5] : 280.0
#     z[2,6] : 0.0
#     z[2,7] : 0.0
#
# * Work counters
#   Solve time (sec)   : 0.00000
