# %%
using JuMP, Cbc

plant = 1:3
bakery = 1:3

m = Model()

@variable(m, x[plant, bakery] >= 0)
@variable(m, y[plant], Bin)

@objective(m, Min, sum(15x[1,1] + 10x[1,2] + 12x[1,3] + 20x[2,1] + 18x[2,2] + 21x[2,3] + 17x[3,1] + 15x[3,2] + 11x[3,3] +
        10000y[1] + 11000y[2] + 9000y[3]))

@constraint(m, binary_1, x[1,1] + x[1,2] + x[1,3] <= 1600 * y[1])
@constraint(m, binary_2, x[2,1] + x[2,2] + x[2,3] <= 1500 * y[2])
@constraint(m, binary_3, x[3,1] + x[3,2] + x[3,3] <= 1200 * y[3])
@constraint(m, demand_1, x[1,1] + x[2,1] + x[3,1] >= 1600)
@constraint(m, demand_2, x[1,2] + x[2,2] + x[3,2] >= 900)
@constraint(m, demand_3, x[1,3] + x[2,3] + x[3,3] >= 1000)

set_optimizer(m, Cbc.Optimizer)

optimize!(m)

solution_summary(m, verbose = true)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.5
# Build Date: Jan  1 1970
#
# command line - Cbc_C_Interface -solve -quit (default strategy 1)
# Continuous objective value is 72033.3 - 0.00 seconds
# Cgl0004I processed model has 6 rows, 12 columns (3 integer (3 of which binary)) and 21 elements
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.466667
# Cbc0038I Pass   1: suminf.    0.46667 (1) obj. 72033.3 iterations 0
# Cbc0038I Solution found of 77900
# Cbc0038I Relaxing continuous gives 77900
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 4 continuous
# Cbc0038I Full problem 6 rows 12 columns, reduced to 1 rows 3 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 77313.3
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.46667 (1) obj. 72033.3 iterations 0
# Cbc0038I Pass   3: suminf.    0.05333 (1) obj. 77313.3 iterations 1
# Cbc0038I Pass   4: suminf.    0.05333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass   5: suminf.    0.05333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass   6: suminf.    0.33333 (1) obj. 77313.3 iterations 4
# Cbc0038I Pass   7: suminf.    0.05333 (1) obj. 77313.3 iterations 3
# Cbc0038I Pass   8: suminf.    0.05333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass   9: suminf.    0.05333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  10: suminf.    0.05333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  11: suminf.    0.05333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  12: suminf.    0.33333 (1) obj. 77313.3 iterations 4
# Cbc0038I Pass  13: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  14: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  15: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  16: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  17: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  18: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  19: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  20: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  21: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  22: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  23: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  24: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  25: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  26: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  27: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  28: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  29: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  30: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I Pass  31: suminf.    0.33333 (1) obj. 77313.3 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 2 continuous
# Cbc0038I Full problem 6 rows 12 columns, reduced to 5 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 77900 - took 0.01 seconds
# Cbc0012I Integer solution of 77900 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 6 rows 12 columns, reduced to 6 rows 10 columns
# Cbc0013I At root node, 2 cuts changed objective from 72033.333 to 77900 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 77900, took 1 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Cuts at root node changed objective from 72033.3 to 77900
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                77900.00000000
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
# * Solver : COIN Branch-and-Cut (Cbc)
#
# * Status
#   Termination status : OPTIMAL
#   Primal status      : FEASIBLE_POINT
#   Dual status        : NO_SOLUTION
#   Result count       : 1
#   Has duals          : false
#   Message from the solver:
#   "Cbc_status          = finished - check isProvenOptimal or isProvenInfeasible to see if solution found (or check value of best solution)
# Cbc_secondaryStatus = search completed with solution
# "
#
# * Candidate solution
#   Objective value      : 77900.0
#   Objective bound      : 77900.0
#   Primal solution :
#     x[1,1] : 699.9999999999998
#     x[1,2] : 900.0
#     x[1,3] : 0.0
#     x[2,1] : 699.9999999999998
#     x[2,2] : 0.0
#     x[2,3] : 0.0
#     x[3,1] : 200.00000000000014
#     x[3,2] : 0.0
#     x[3,3] : 1000.0
#     y[1] : 0.9999999999999999
#     y[2] : 0.9999999999999999
#     y[3] : 1.0
#
# * Work counters
#   Solve time (sec)   : 0.01800
