# %%
using JuMP, Cbc, DelimitedFiles, NamedArrays

whdata, whheader = readdlm("smwarehouse.csv",',',header=true);

facilities = whheader[2:end]
stores = convert(Array,whdata[2:end,1])

fmat = Matrix(whdata[1:1,2:end])
f = Dict(zip(facilities,fmat[1,:]))
cmat = Matrix(whdata[2:end,2:end])
c = NamedArray(cmat, (stores,facilities), ("store","facility"))

m=Model()

@variable(m,open[facilities],Bin)
@variable(m,assign[stores,facilities],Bin)

@objective(m,Min,
    sum(open[j]f[j] for j in facilities)
    +sum(c[i,j]assign[i,j] for i in stores for j in facilities))

@constraint(m,assignall[i in stores],
    sum(assign[i,j] for j in facilities)==1)
    
@constraint(m,onlyifopen1[j in facilities],
        sum(assign[i,j] for i in stores) 
                <= length(facilities)open[j])
    
# @constraint(m, onlyifopen2[i in stores, j in facilities],
#        assign[i,j] <= open[j])    
    
set_optimizer(m, Cbc.Optimizer)

# The following command disables some advanced features of solver to better illustrate
# potential impact of the different formulation
# CAUTION: You would generally never want to do this!
#set_optimizer_attribute(m,"cutsOnOff","off")
# set_silent(m)

# We limit solver time to 30 seconds. 
# It will provide bounds on optimal value if it hasn't solved within this limit
set_time_limit_sec(m,30)

optimize!(m)


# print total cost
println("Obtained solution cost: \$", objective_value(m))

print("open facilities: ")
for j in facilities
    if value(open[j]) > 0.1
        print(j, ", ")
    end
end
println("\n")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.5
# Build Date: Jan  1 1970
#
# command line - Cbc_C_Interface -seconds 30.0 -solve -quit (default strategy 1)
# seconds was changed from 1e+100 to 30
# Continuous objective value is 138 - 0.00 seconds
# Cgl0004I processed model has 8 rows, 20 columns (20 integer (20 of which binary)) and 36 elements
# Cutoff increment increased from 1e-05 to 1.9999
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    1.00000 (4) obj. 138 iterations 0
# Cbc0038I Solution found of 288
# Cbc0038I Before mini branch and bound, 16 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8 rows 20 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 271.2
# Cbc0038I Pass   2: suminf.    1.00000 (4) obj. 138 iterations 0
# Cbc0038I Pass   3: suminf.    0.33600 (1) obj. 271.2 iterations 5
# Cbc0038I Pass   4: suminf.    0.25000 (1) obj. 250.5 iterations 1
# Cbc0038I Pass   5: suminf.    0.50000 (2) obj. 213 iterations 1
# Cbc0038I Pass   6: suminf.    0.50000 (2) obj. 213 iterations 0
# Cbc0038I Pass   7: suminf.    0.66853 (4) obj. 271.2 iterations 1
# Cbc0038I Pass   8: suminf.    0.51600 (2) obj. 271.2 iterations 2
# Cbc0038I Pass   9: suminf.    0.98400 (2) obj. 271.2 iterations 2
# Cbc0038I Pass  10: suminf.    0.75000 (2) obj. 259.5 iterations 2
# Cbc0038I Pass  11: suminf.    0.98400 (2) obj. 271.2 iterations 2
# Cbc0038I Pass  12: suminf.    0.81600 (3) obj. 271.2 iterations 6
# Cbc0038I Pass  13: suminf.    0.81600 (3) obj. 271.2 iterations 0
# Cbc0038I Pass  14: suminf.    0.96581 (3) obj. 271.2 iterations 5
# Cbc0038I Pass  15: suminf.    0.25000 (1) obj. 240.5 iterations 2
# Cbc0038I Pass  16: suminf.    0.13600 (1) obj. 271.2 iterations 3
# Cbc0038I Pass  17: suminf.    0.50000 (1) obj. 253 iterations 2
# Cbc0038I Pass  18: suminf.    0.25000 (1) obj. 240.5 iterations 3
# Cbc0038I Pass  19: suminf.    0.33600 (1) obj. 271.2 iterations 5
# Cbc0038I Pass  20: suminf.    0.33600 (1) obj. 271.2 iterations 0
# Cbc0038I Pass  21: suminf.    0.25000 (1) obj. 250.5 iterations 1
# Cbc0038I Pass  22: suminf.    0.55600 (2) obj. 271.2 iterations 2
# Cbc0038I Pass  23: suminf.    0.05600 (1) obj. 271.2 iterations 1
# Cbc0038I Pass  24: suminf.    0.25000 (1) obj. 236.5 iterations 2
# Cbc0038I Pass  25: suminf.    0.45517 (3) obj. 271.2 iterations 1
# Cbc0038I Pass  26: suminf.    0.17600 (1) obj. 271.2 iterations 2
# Cbc0038I Pass  27: suminf.    0.50000 (1) obj. 255 iterations 3
# Cbc0038I Pass  28: suminf.    0.82400 (2) obj. 271.2 iterations 4
# Cbc0038I Pass  29: suminf.    0.50000 (1) obj. 255 iterations 3
# Cbc0038I Pass  30: suminf.    0.73600 (3) obj. 271.2 iterations 6
# Cbc0038I Pass  31: suminf.    0.73600 (3) obj. 271.2 iterations 0
# Cbc0038I Rounding solution of 274 is better than previous of 288
#
# Cbc0038I Before mini branch and bound, 7 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8 rows 20 columns, reduced to 5 rows 10 columns
# Cbc0038I Mini branch and bound improved solution from 274 to 262 (0.03 seconds)
# Cbc0038I Round again with cutoff of 235.6
# Cbc0038I Pass  31: suminf.    1.00000 (4) obj. 138 iterations 0
# Cbc0038I Pass  32: suminf.    0.54800 (2) obj. 235.6 iterations 4
# Cbc0038I Pass  33: suminf.    0.54800 (2) obj. 235.6 iterations 0
# Cbc0038I Pass  34: suminf.    0.54800 (2) obj. 235.6 iterations 1
# Cbc0038I Pass  35: suminf.    0.54800 (2) obj. 235.6 iterations 0
# Cbc0038I Pass  36: suminf.    0.54800 (2) obj. 235.6 iterations 0
# Cbc0038I Pass  37: suminf.    1.22353 (4) obj. 235.6 iterations 5
# Cbc0038I Pass  38: suminf.    0.50000 (2) obj. 211 iterations 2
# Cbc0038I Pass  39: suminf.    0.99200 (2) obj. 235.6 iterations 3
# Cbc0038I Pass  40: suminf.    0.75000 (2) obj. 223.5 iterations 2
# Cbc0038I Pass  41: suminf.    1.00000 (3) obj. 218 iterations 3
# Cbc0038I Pass  42: suminf.    0.64800 (3) obj. 235.6 iterations 1
# Cbc0038I Pass  43: suminf.    1.14800 (3) obj. 235.6 iterations 2
# Cbc0038I Pass  44: suminf.    1.14800 (3) obj. 235.6 iterations 0
# Cbc0038I Pass  45: suminf.    0.64800 (3) obj. 235.6 iterations 1
# Cbc0038I Pass  46: suminf.    0.64800 (3) obj. 235.6 iterations 1
# Cbc0038I Pass  47: suminf.    0.86800 (3) obj. 235.6 iterations 6
# Cbc0038I Pass  48: suminf.    0.63200 (2) obj. 235.6 iterations 1
# Cbc0038I Pass  49: suminf.    0.25000 (1) obj. 216.5 iterations 3
# Cbc0038I Pass  50: suminf.    0.36800 (1) obj. 235.6 iterations 3
# Cbc0038I Pass  51: suminf.    0.36800 (2) obj. 235.6 iterations 1
# Cbc0038I Pass  52: suminf.    0.36800 (1) obj. 235.6 iterations 1
# Cbc0038I Pass  53: suminf.    0.86800 (3) obj. 235.6 iterations 2
# Cbc0038I Pass  54: suminf.    0.86800 (3) obj. 235.6 iterations 0
# Cbc0038I Pass  55: suminf.    0.36800 (2) obj. 235.6 iterations 3
# Cbc0038I Pass  56: suminf.    0.56800 (2) obj. 235.6 iterations 2
# Cbc0038I Pass  57: suminf.    0.56800 (2) obj. 235.6 iterations 0
# Cbc0038I Pass  58: suminf.    0.56800 (2) obj. 235.6 iterations 1
# Cbc0038I Pass  59: suminf.    0.56800 (2) obj. 235.6 iterations 1
# Cbc0038I Pass  60: suminf.    0.56800 (2) obj. 235.6 iterations 1
# Cbc0038I Rounding solution of 254 is better than previous of 262
#
# Cbc0038I Before mini branch and bound, 8 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8 rows 20 columns, reduced to 4 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of 206.32
# Cbc0038I Reduced cost fixing fixed 3 variables on major pass 4
# Cbc0038I Pass  60: suminf.    1.00000 (4) obj. 138 iterations 0
# Cbc0038I Pass  61: suminf.    0.63360 (3) obj. 206.32 iterations 5
# Cbc0038I Pass  62: suminf.    0.63360 (3) obj. 206.32 iterations 0
# Cbc0038I Pass  63: suminf.    0.63360 (3) obj. 206.32 iterations 1
# Cbc0038I Pass  64: suminf.    0.63360 (3) obj. 206.32 iterations 0
# Cbc0038I Pass  65: suminf.    0.63360 (3) obj. 206.32 iterations 1
# Cbc0038I Pass  66: suminf.    1.63143 (6) obj. 206.32 iterations 3
# Cbc0038I Pass  67: suminf.    1.63143 (6) obj. 206.32 iterations 0
# Cbc0038I Pass  68: suminf.    1.23360 (4) obj. 206.32 iterations 6
# Cbc0038I Pass  69: suminf.    1.23360 (4) obj. 206.32 iterations 0
# Cbc0038I Pass  70: suminf.    0.73360 (2) obj. 206.32 iterations 3
# Cbc0038I Pass  71: suminf.    0.73360 (2) obj. 206.32 iterations 0
# Cbc0038I Pass  72: suminf.    0.76640 (2) obj. 206.32 iterations 1
# Cbc0038I Pass  73: suminf.    0.75000 (2) obj. 205.5 iterations 2
# Cbc0038I Pass  74: suminf.    0.50000 (2) obj. 193 iterations 1
# Cbc0038I Pass  75: suminf.    0.50000 (2) obj. 193 iterations 0
# Cbc0038I Pass  76: suminf.    0.73360 (2) obj. 206.32 iterations 1
# Cbc0038I Pass  77: suminf.    0.73360 (2) obj. 206.32 iterations 0
# Cbc0038I Pass  78: suminf.    0.73360 (2) obj. 206.32 iterations 1
# Cbc0038I Pass  79: suminf.    0.73360 (2) obj. 206.32 iterations 0
# Cbc0038I Pass  80: suminf.    0.73360 (2) obj. 206.32 iterations 0
# Cbc0038I Pass  81: suminf.    0.63360 (3) obj. 206.32 iterations 3
# Cbc0038I Pass  82: suminf.    0.63360 (3) obj. 206.32 iterations 0
# Cbc0038I Pass  83: suminf.    0.63360 (3) obj. 206.32 iterations 2
# Cbc0038I Pass  84: suminf.    0.63360 (3) obj. 206.32 iterations 0
# Cbc0038I Pass  85: suminf.    0.63360 (3) obj. 206.32 iterations 2
# Cbc0038I Pass  86: suminf.    0.63360 (3) obj. 206.32 iterations 0
# Cbc0038I Pass  87: suminf.    0.63360 (3) obj. 206.32 iterations 2
# Cbc0038I Pass  88: suminf.    0.63360 (3) obj. 206.32 iterations 1
# Cbc0038I Pass  89: suminf.    0.63360 (3) obj. 206.32 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of 254 - took 0.03 seconds
# Cbc0012I Integer solution of 254 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0012I Integer solution of 242 found by DiveCoefficient after 7 iterations and 0 nodes (0.04 seconds)
# Cbc0031I 5 added rows had average density of 6.2
# Cbc0013I At root node, 5 cuts changed objective from 138 to 242 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 18 row cuts average 2.4 elements, 0 column cuts Obtained solution cost: $242.0
# open facilities: W1, W3,
# (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 8 row cuts average 7.8 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 5 row cuts average 2.6 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 18 row cuts average 6.8 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 242, took 7 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 5 variables fixed on reduced cost
# Cuts at root node changed objective from 138 to 242
# Probing was tried 3 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 3 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 3 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                242.00000000
# Enumerated nodes:               0
# Total iterations:               7
# Time (CPU seconds):             0.04
# Time (Wallclock seconds):       0.04
#
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.04

# %%
using JuMP, Cbc, DelimitedFiles, NamedArrays

whdata, whheader = readdlm("bigwarehouse.csv",',',header=true);

facilities = whheader[2:end]
stores = convert(Array,whdata[2:end,1])

fmat = Matrix(whdata[1:1,2:end])
f = Dict(zip(facilities,fmat[1,:]))
cmat = Matrix(whdata[2:end,2:end])

c = NamedArray(cmat, (stores,facilities), ("store","facility"))

m=Model()

@variable(m,open[facilities],Bin)
@variable(m,assign[stores,facilities],Bin)

@objective(m,Min,
    sum(open[j]f[j] for j in facilities)
    +sum(c[i,j]assign[i,j] for i in stores for j in facilities))

@constraint(m,assignall[i in stores],
    sum(assign[i,j] for j in facilities)==1)
    
@constraint(m,onlyifopen1[j in facilities],
        sum(assign[i,j] for i in stores) 
                <= length(facilities)open[j])
    
# @constraint(m, onlyifopen2[i in stores, j in facilities],
#        assign[i,j] <= open[j])    
    
set_optimizer(m, Cbc.Optimizer)

# The following command disables some advanced features of solver to better illustrate
# potential impact of the different formulation
# CAUTION: You would generally never want to do this!
#set_optimizer_attribute(m,"cutsOnOff","off")
# set_silent(m)

# We limit solver time to 30 seconds. 
# It will provide bounds on optimal value if it hasn't solved within this limit
set_time_limit_sec(m,30)

optimize!(m)


# print total cost
println("Obtained solution cost: \$", objective_value(m))

print("open facilities: ")
for j in facilities
    if value(open[j]) > 0.1
        print(j, ", ")
    end
end
println("\n")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.5
# Build Date: Jan  1 1970
#
# command line - Cbc_C_Interface -seconds 30.0 -solve -quit (default strategy 1)
# seconds was changed from 1e+100 to 30
# Continuous objective value is 200 - 0.01 seconds
# Cgl0004I processed model has 200 rows, 10100 columns (10100 integer (10100 of which binary)) and 20100 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 100 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    1.00000 (100) obj. 200 iterations 0
# Cbc0038I Pass   2: suminf.    0.79000 (79) obj. 4358 iterations 21
# Cbc0038I Pass   3: suminf.    0.67000 (67) obj. 6734 iterations 12
# Cbc0038I Pass   4: suminf.    0.53000 (53) obj. 9506 iterations 14
# Cbc0038I Pass   5: suminf.    0.35000 (35) obj. 13070 iterations 18
# Cbc0038I Pass   6: suminf.    0.07000 (7) obj. 18614 iterations 28
# Cbc0038I Solution found of 20000
# Cbc0038I Before mini branch and bound, 10000 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 200 rows 10100 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.49 seconds)
# Cbc0038I Round again with cutoff of 18019.1
# Cbc0038I Pass   7: suminf.    1.00000 (100) obj. 200 iterations 0
# Cbc0038I Pass   8: suminf.    0.85000 (85) obj. 3170 iterations 15
# Cbc0038I Pass   9: suminf.    0.63000 (63) obj. 7526 iterations 22
# Cbc0038I Pass  10: suminf.    0.47000 (47) obj. 10694 iterations 16
# Cbc0038I Pass  11: suminf.    0.22000 (22) obj. 15644 iterations 25
# Cbc0038I Pass  12: suminf.    0.12000 (12) obj. 17624 iterations 10
# Cbc0038I Pass  13: suminf.    0.10450 (11) obj. 18019.1 iterations 18
# Cbc0038I Pass  14: suminf.    0.10450 (11) obj. 18019.1 iterations 0
# Cbc0038I Pass  15: suminf.    0.10450 (11) obj. 18019.1 iterations 2
# Cbc0038I Pass  16: suminf.    0.10450 (11) obj. 18019.1 iterations 0
# Cbc0038I Pass  17: suminf.    0.10450 (11) obj. 18019.1 iterations 1
# Cbc0038I Pass  18: suminf.    0.63481 (11) obj. 18019.1 iterations 59
# Cbc0038I Pass  19: suminf.    0.18950 (10) obj. 18019.1 iterations 17
# Cbc0038I Pass  20: suminf.    0.10950 (8) obj. 18019.1 iterations 28
# Cbc0038I Pass  21: suminf.    0.10950 (8) obj. 18019.1 iterations 0
# Cbc0038I Pass  22: suminf.    0.10950 (8) obj. 18019.1 iterations 15
# Cbc0038I Pass  23: suminf.    0.10950 (8) obj. 18019.1 iterations 0
# Cbc0038I Pass  24: suminf.    0.10950 (8) obj. 18019.1 iterations 30
# Cbc0038I Pass  25: suminf.    0.93277 (13) obj. 18019.1 iterations 118
# Cbc0038I Pass  26: suminf.    0.30450 (12) obj. 18019.1 iterations 57
# Cbc0038I Pass  27: suminf.    0.32450 (12) obj. 18019.1 iterations 19
# Cbc0038I Pass  28: suminf.    0.32450 (12) obj. 18019.1 iterations 0
# Cbc0038I Pass  29: suminf.    0.30450 (12) obj. 18019.1 iterations 34
# Cbc0038I Pass  30: suminf.    0.30450 (12) obj. 18019.1 iterations 0
# Cbc0038I Pass  31: suminf.    0.32450 (12) obj. 18019.1 iterations 26
# Cbc0038I Pass  32: suminf.    0.18417 (15) obj. 18019.1 iterations 117
# Cbc0038I Pass  33: suminf.    0.18000 (13) obj. 18019 iterations 112
# Cbc0038I Pass  34: suminf.    0.18050 (12) obj. 18019.1 iterations 142
# Cbc0038I Pass  35: suminf.    0.15000 (11) obj. 18013 iterations 131
# Cbc0038I Pass  36: suminf.    0.18050 (11) obj. 18019.1 iterations 137
# Cbc0038I Rounding solution of 16209 is better than previous of 20000
#
# Cbc0038I Before mini branch and bound, 9839 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 200 rows 10100 columns, reduced to 89 rows 179 columns
# Cbc0038I Mini branch and bound improved solution from 16209 to 12392 (0.69 seconds)
# Cbc0038I Round again with cutoff of 9952.8
# Cbc0038I Pass  36: suminf.    1.00000 (100) obj. 200 iterations 0
# Cbc0038I Pass  37: suminf.    0.75000 (75) obj. 5150 iterations 25
# Cbc0038I Pass  38: suminf.    0.59000 (59) obj. 8318 iterations 16
# Cbc0038I Pass  39: suminf.    0.76400 (51) obj. 9952.8 iterations 33
# Cbc0038I Pass  40: suminf.    0.51000 (51) obj. 9902 iterations 1
# Cbc0038I Pass  41: suminf.    0.76400 (51) obj. 9952.8 iterations 2
# Cbc0038I Pass  42: suminf.    0.68900 (49) obj. 9952.8 iterations 4
# Cbc0038I Pass  43: suminf.    0.50000 (49) obj. 9915 iterations 7
# Cbc0038I Pass  44: suminf.    0.68900 (49) obj. 9952.8 iterations 7
# Cbc0038I Pass  45: suminf.    1.30509 (47) obj. 9952.8 iterations 19
# Cbc0038I Pass  46: suminf.    0.47000 (45) obj. 9929 iterations 26
# Cbc0038I Pass  47: suminf.    0.58900 (45) obj. 9952.8 iterations 29
# Cbc0038I Pass  48: suminf.    0.47000 (45) obj. 9929 iterations 24
# Cbc0038I Pass  49: suminf.    0.58900 (45) obj. 9952.8 iterations 22
# Cbc0038I Pass  50: suminf.    0.95100 (45) obj. 9952.8 iterations 27
# Cbc0038I Pass  51: suminf.    0.95100 (45) obj. 9952.8 iterations 29
# Cbc0038I Pass  52: suminf.    0.95100 (45) obj. 9952.8 iterations 9
# Cbc0038I Pass  53: suminf.    0.95100 (45) obj. 9952.8 iterations 3
# Cbc0038I Pass  54: suminf.    0.95100 (45) obj. 9952.8 iterations 7
# Cbc0038I Pass  55: suminf.    0.95100 (45) obj. 9952.8 iterations 1
# Cbc0038I Pass  56: suminf.    0.95100 (45) obj. 9952.8 iterations 10
# Cbc0038I Pass  57: suminf.    0.95100 (45) obj. 9952.8 iterations 3
# Cbc0038I Pass  58: suminf.    0.95100 (45) obj. 9952.8 iterations 7
# Cbc0038I Pass  59: suminf.    0.95100 (45) obj. 9952.8 iterations 1
# Cbc0038I Pass  60: suminf.    0.95100 (45) obj. 9952.8 iterations 8
# Cbc0038I Pass  61: suminf.    0.95100 (45) obj. 9952.8 iterations 3
# Cbc0038I Pass  62: suminf.    0.95100 (45) obj. 9952.8 iterations 7
# Cbc0038I Pass  63: suminf.    0.72492 (40) obj. 9952.8 iterations 62
# Cbc0038I Pass  64: suminf.    0.48000 (38) obj. 9940 iterations 71
# Cbc0038I Pass  65: suminf.    0.54400 (38) obj. 9952.8 iterations 79
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9919 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.86 seconds)
# Cbc0038I After 0.86 seconds - Feasibility pump exiting with objective of 12392 - took 0.43 seconds
# Cbc0012I Integer solution of 12392 found by feasibility pump after 0 iterations and 0 nodes (0.86 seconds)
# Cbc0012I Integer solution of 3031 found by DiveCoefficient after 16402 iterations and 0 nodes (12.34 seconds)
# Cbc0031I 1131 added rows had average density of 14.664014
# Cbc0013I At root node, 1131 cuts changed objective from 200 to 3031 in 31 passes
# Cbc0014I Cut generator 0 (Probing) - 1395 row cuts average 3.1 elements, 0 column cuts (302 active)  in 1.826 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 234 row cuts average 175.2 elements, 0 column cuts (0 active)  in 1.249 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1191 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.251 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.070 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1376 row cuts average 11.2 elements, 0 column cuts (0 active)  in 0.202 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 285 row cuts average 144.5 elements, 0 column cuts (0 active)  in 0.201 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 3031, took 16402 iterations and 0 nodes (12.37 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 200 to 3031
# Probing was tried 31 times and created 1395 cuts of which 302 were active after adding rounds of cuts (1.826 seconds)
# Gomory was tried 31 times and created 234 cuts of which 0 were active after adding rounds of cuts (1.249 seconds)
# Knapsack was tried 31 times and created 1191 cuts of which 0 were active after adding rounds of cuts (0.251 seconds)
# Clique was tried 31 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.070 seconds)
# MixedIntegerRounding2 was tried 31 times and created 1376 cuts of which 0 were active after adding rounds of cuts (0.202 seconds)
# FlowCover was tried 31 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)Obtained solution cost: $3031.0
# open facilities: 27, 35, 62, 66, 71, 86,
#
#
# TwoMirCuts was tried 31 times and created 285 cuts of which 0 were active after adding rounds of cuts (0.201 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3031.00000000
# Enumerated nodes:               0
# Total iterations:               16402
# Time (CPU seconds):             12.41
# Time (Wallclock seconds):       12.41
#
# Total time (CPU seconds):       12.41   (Wallclock seconds):       12.41
